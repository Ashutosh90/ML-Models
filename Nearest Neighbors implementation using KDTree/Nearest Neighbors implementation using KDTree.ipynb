# %%
#importing libraries
import pandas as pd
from sklearn.neighbors import KDTree

# %%
#loading the dataset
df = pd.read_csv("votes_skills_anon.csv")
df.head()
# Out:
#    SUID                    univid                                   response
# 0   538  5c9e7a6834cda4f3677e662b                           Internationality
# 1  2285  5c9e373c34cda4f3677e14ef  Practical relevance / professionalization
# 2  2285  5c9e7d8334cda4f3677e6b4f                           Internationality
# 3  2285  5e84b8a01ead1a77be3bd3a8           Soft skills and digital literacy
# 4  2285  5c9e471734cda4f3677e2ed7                           Internationality

# %% [markdown]
# #### Each row corresponds to a vote where:
# #### SUID is the Unique ID of the voter
# #### univid: the unique ID of the institution
# #### response: the voted skill

# %%
#grouping by institution and skill (response)
skills = df.groupby(["univid", "response"])["response"].count().reset_index(name='value')
skills.head()
# Out:
#                      univid                                   response  value
# 0  5c9e345f34cda4f3677e1047                        Academic excellence     10
# 1  5c9e345f34cda4f3677e1047                           Internationality     24
# 2  5c9e345f34cda4f3677e1047  Practical relevance / professionalization     10
# 3  5c9e345f34cda4f3677e1047           Soft skills and digital literacy      7
# 4  5c9e345f34cda4f3677e1047                             Specialization     18

# %%
univSkills = skills.pivot_table(values="value", columns="response", index=["univid"])
univSkills.head()
# Out:
# response                  Academic excellence  Internationality  \
# univid
# 5c9e345f34cda4f3677e1047                 10.0              24.0
# 5c9e349434cda4f3677e109f                  5.0              10.0
# 5c9e34a834cda4f3677e10bd                  8.0              10.0
# 5c9e34ae34cda4f3677e10c7                  1.0              17.0
# 5c9e34d534cda4f3677e1107                 10.0              11.0
#
# response                  Practical relevance / professionalization  \
# univid
# 5c9e345f34cda4f3677e1047                                       10.0
# 5c9e349434cda4f3677e109f                                       12.0
# 5c9e34a834cda4f3677e10bd                                        8.0
# 5c9e34ae34cda4f3677e10c7                                       17.0
# 5c9e34d534cda4f3677e1107                                       15.0
#
# response                  Soft skills and digital literacy  Specialization
# univid
# 5c9e345f34cda4f3677e1047                               7.0            18.0
# 5c9e349434cda4f3677e109f                               9.0            15.0
# 5c9e34a834cda4f3677e10bd                               6.0             8.0
# 5c9e34ae34cda4f3677e10c7                              14.0            17.0
# 5c9e34d534cda4f3677e1107                              10.0            24.0

# %%
univSkills.sum(axis=1).head()
# Out:
# univid
# 5c9e345f34cda4f3677e1047    69.0
# 5c9e349434cda4f3677e109f    51.0
# 5c9e34a834cda4f3677e10bd    40.0
# 5c9e34ae34cda4f3677e10c7    66.0
# 5c9e34d534cda4f3677e1107    70.0
# dtype: float64

# %%
#changing values into percentage
univSkills = univSkills.div(univSkills.sum(axis=1), axis=0)
univSkills.fillna(0, inplace=True )
univSkills.head()
# Out:
# response                  Academic excellence  Internationality  \
# univid
# 5c9e345f34cda4f3677e1047             0.144928          0.347826
# 5c9e349434cda4f3677e109f             0.098039          0.196078
# 5c9e34a834cda4f3677e10bd             0.200000          0.250000
# 5c9e34ae34cda4f3677e10c7             0.015152          0.257576
# 5c9e34d534cda4f3677e1107             0.142857          0.157143
#
# response                  Practical relevance / professionalization  \
# univid
# 5c9e345f34cda4f3677e1047                                   0.144928
# 5c9e349434cda4f3677e109f                                   0.235294
# 5c9e34a834cda4f3677e10bd                                   0.200000
# 5c9e34ae34cda4f3677e10c7                                   0.257576
# 5c9e34d534cda4f3677e1107                                   0.214286
#
# response                  Soft skills and digital literacy  Specialization
# univid
# 5c9e345f34cda4f3677e1047                          0.101449        0.260870
# 5c9e349434cda4f3677e109f                          0.176471        0.294118
# 5c9e34a834cda4f3677e10bd                          0.150000        0.200000
# 5c9e34ae34cda4f3677e10c7                          0.212121        0.257576
# 5c9e34d534cda4f3677e1107                          0.142857        0.342857

# %%
#Processing the data to find neighbors
tree = KDTree(univSkills)

# %%
#findind the top 3 nearest neighbours of first university
dist, ind = tree.query(univSkills[0:], k=4)
univSkills.iloc[ind.tolist()[0]]
# Out:
# response                  Academic excellence  Internationality  \
# univid
# 5c9e345f34cda4f3677e1047             0.144928          0.347826
# 5c9e519734cda4f3677e4003             0.159091          0.340909
# 5c9e3c6a34cda4f3677e1d67             0.157895          0.342105
# 5c9e895334cda4f3677e7141             0.126126          0.333333
#
# response                  Practical relevance / professionalization  \
# univid
# 5c9e345f34cda4f3677e1047                                   0.144928
# 5c9e519734cda4f3677e4003                                   0.136364
# 5c9e3c6a34cda4f3677e1d67                                   0.131579
# 5c9e895334cda4f3677e7141                                   0.180180
#
# response                  Soft skills and digital literacy  Specialization
# univid
# 5c9e345f34cda4f3677e1047                          0.101449        0.260870
# 5c9e519734cda4f3677e4003                          0.113636        0.250000
# 5c9e3c6a34cda4f3677e1d67                          0.131579        0.236842
# 5c9e895334cda4f3677e7141                          0.117117        0.243243
